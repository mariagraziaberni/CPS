# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
import numpy as np
import matplotlib.pyplot as plt 
import torch as T 
import torch.nn as nn 
import torch.nn.functional as F 
import torch.optim as optim 
import os 
from utility import *
from Parkour import *

# %%
from agent import *

# %%
class State(): 
    
    def __init__(self,x_, y_, theta_): 
        
        if not (x_ is None or y_ is None or theta_ is None ):    #non ricordo perchè avevo messo questo 
            
            self.x = x_ 
            self.y = y_ 
            self.theta = theta_ 
            
        else : 
            
            self.x = 0 
            self.y= 0
            self.theta= 0
            
    def __str__(self): 
        return str(self.x)+","+str(self.y)+","+str(self.theta)

# %%
class Controller(): 
    
    def __init__(self, goal, start, R_=0.0325,L_=0.1,dT=0.1,v_=5,arrive_distance=0.3): 
        
        self.R = R_ 
        
        self.L = L_ 
        
        self.E = 0   #cumulative error for integration 
        
        self.old_e = 0
        
        self.v = v_
        
        self.dt = dT 
        
        self.arrive_distance = arrive_distance 
        
        self.goal = goal 
        
        self.current_position = start 
        
        self.route_x = [] 
        
        self.route_y = [] 
        
        self.route_theta = [] 
        
    def track_route(self): 
        
        self.route_x.append(self.current_position.x)
        
        self.route_y.append(self.current_position.y)
        
        self.route_theta.append(self.current_position.theta)
        
    def give_route(self): 
        
        return self.route_x, self.route_y, self.route_theta
    
    def fixAngle(self, angle):
            
        return np.arctan2(np.sin(angle), np.cos(angle))
    
    
    def iterate(self): 
        
        dx = self.goal.x - self.current_position.x 
        
        dy = self.goal.y -self.current_position.y 
        
        
        g_theta = np.arctan2(dy, dx)
        
        alpha = g_theta - self.current_position.theta
        
        
        e = np.arctan2(np.sin(alpha), np.cos(alpha))
        
        
        e_p = e
        
        e_I = self.E + e 
        
        e_D = e -self.old_e 
        
        self.E = self.E + e
        
        self.old_e = e
        
        a =np.array([e_p,e_I,e_D])
        
        return a 
    
    
    def iterate_with_gains(self,k,ki,kd): 
        
        dx = self.goal.x - self.current_position.x  
        
        dy = self.goal.y -self.current_position.y   
   
        g_theta = np.arctan2(dy, dx)
        
    
        alpha = g_theta - self.current_position.theta
   
        e = np.arctan2(np.sin(alpha), np.cos(alpha))

        e_p = e 
        
        e_I = self.E + e 
        
        e_D = e -self.old_e 
        
        self.E = self.E + e
        
        self.old_e = e
        
        w = k*e_p + ki*e_I + kd*e_D
        
        #w = np.arctan2(np.sin(w), np.cos(w))
        
        return w
    
    def make_action(self, w):
        #self.tot_steps += 1
        #qyesi due nn eran ui
       # theta_dt = w
       # self.current_position.theta = (self.fixAngle(
       #     self.current_position.theta + self.fixAngle(theta_dt * self.dt))).squeeze(-1)
        #fin qui
        x_dt = self.v*np.cos(self.current_position.theta)     #process model ,magari dovuto ad attrito etc 
        
        y_dt = self.v*np.sin(self.current_position.theta)
        
        #theta_dt = w
        
        a = self.current_position.x + x_dt * self.dt
        
        b = self.current_position.y + y_dt * self.dt
        
       # if (a >=30 or a<=-30) or (b >=30 or b<=-30):
            
          #  return 
        

        self.current_position.x = self.current_position.x + x_dt * self.dt
        
        self.current_position.y = self.current_position.y + y_dt * self.dt
        
        theta_dt = w
        self.current_position.theta = (self.fixAngle(
            self.current_position.theta + self.fixAngle(theta_dt * self.dt))).squeeze(-1)
        #fin qui
        
       # self.current_position.theta = (self.fixAngle(
       #     self.current_position.theta + self.fixAngle(theta_dt * self.dt))).squeeze(-1)
        
        return
    
    
        
    
    def isArrived(self):
        # print("Arrive check:", str(abs(self.current.x - self.goal.x)),
        #       str(abs(self.current.y - self.goal.y)))
        current_state = np.array([self.current_position.x, self.current_position.y])
        goal_state = np.array([self.goal.x, self.goal.y])
        #goal_state = np.array([self.goal.x, self.goal.y])
        difference = current_state - goal_state

        distance_err = difference @ difference.T
        if distance_err < self.arrive_distance:
            #print("Total number of steps to reach goal : ", self.tot_steps) 
            return True
        else:
            return False

# %%
spatial_state = State(-25,20,np.radians(90))

# %%
target = State(20,-20,0)

# %%
controller = Controller(target,spatial_state)

# %%
error_state = controller.iterate()

# %%
agent = Agent(error_state.shape[0],chkpt_dir = "obstacle_model",device='cpu')
# Out:
# cpu

# %%
EPISODES = 8000
best_score = -111000
score_history = [] 
expl_noise = 0.25

# %%
np.random.seed(15)

# %%
test = False

# %%
for i in range(1000): 
    
    print(i, end='\r')
    
    a = np.random.uniform(-30,30,4)
    
    b = np.random.uniform(0,90,2)
    
    spatial_state = State(a[0],a[1],np.radians(b[0]))
    
    target = State(a[2],a[3],np.radians(b[1]))
    
    #spatial_state = State(-25,20,np.radians(90))   #I have to redefine it because it change with the time 
    
    controller = Controller(target,spatial_state)
    
    done = False 
    
    error_state = controller.iterate() 
    
    score = 0 
    
    expl_noise = 0.25 
    
    num_steps = 0 
    
    h = 0
    
    while not done: 
        
        h+=1 
        
        num_steps += 1 
        
        if test: 
            
            action = controller.iterate_with_gains(-agent.actor.mu.weight[0].item(),-agent.actor.mu.weight[1].item(),-agent.actor.mu.weight[2].item())
            
        else:
            action = agent.choose_action(error_state, expl_noise)
        
        #if (h%100==0): 
            
           # print("w = ",action)
            
        controller.make_action(action) 
        
        done_ = controller.isArrived() 
        
        if(done_): 
            print("successo")
            
        new_error_state = controller.iterate() 
        
        if done_ : 
            reward = 200 
            
        else: 
            
            reward = -new_error_state[0]**2
            
        #new_error_state = controller.iterate() 
        
        done = done_ 
        
        if num_steps>=800: 
            done = True 
            print("insuccesso")
        if not test:
            agent.store_transition(error_state, action, reward, new_error_state, done)
        
        error_state = new_error_state 
        if not test:
            agent.train() 
        
        score += reward 
        
        if (i%50==0): 
            
            controller.track_route()
            
            if(done==True): 
                
                a,b,c = controller.give_route()
                parkour = Parkour()
                parkour.drawPlot(a, b, c, show=True)
                
    score_history.append(score) 
    
    avg_score = np.mean(score_history[-50:])
    
    if avg_score > best_score: 
        
        best_score = avg_score 
        if not test:
            
            agent.save_models() 
        
    if(i%10==0): 
        
            print("Results during training procedure:") 
            
            print('episode ', i, 'score %.1f' % score, 'average score %.1f' % avg_score)
# Out:
# insuccesso
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# Results during training procedure:
# episode  0 score -6857.1 average score -6857.1
# End of warmup
# insuccesso
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# insuccesso
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# insuccesso
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# Results during training procedure:
# episode  10 score 188.1 average score -967.9
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# insuccesso
# successo
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# Results during training procedure:
# episode  20 score 199.2 average score -505.4
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# Results during training procedure:
# episode  30 score 198.5 average score -279.9
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# Results during training procedure:
# episode  40 score 193.9 average score -165.2
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# Results during training procedure:
# episode  50 score 199.1 average score 40.0
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# insuccesso
# Results during training procedure:
# episode  60 score -2528.0 average score 98.1
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# Results during training procedure:
# episode  70 score 138.0 average score 132.7
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# Results during training procedure:
# episode  80 score 198.3 average score 130.6
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# Results during training procedure:
# episode  90 score 181.2 average score 128.0
# successo
# successo
# successo
# insuccesso
# successo
# successo
# successo
# successo
# successo
# successo
# Results during training procedure:
# episode  100 score 143.4 average score 71.2
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# Results during training procedure:
# episode  110 score 180.3 average score 118.6
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# Results during training procedure:
# episode  120 score 197.5 average score 121.2
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# Results during training procedure:
# episode  130 score 108.3 average score 116.4
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# Results during training procedure:
# episode  140 score 197.2 average score 115.6
# successo
# successo
# successo
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# Results during training procedure:
# episode  150 score 199.3 average score 171.5
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# successo
# Results during training procedure:
# episode  160 score 152.0 average score 179.4
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# Results during training procedure:
# episode  170 score 191.3 average score 177.5
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# successo
# 179
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-85387d38133c> in <module>
#      72         error_state = new_error_state
#      73         if not test:
# ---> 74             agent.train()
#      75
#      76         score += reward
#
# ~/Documenti/Università/CPS/agent.py in train(self)
#     456         critic_loss = q1_loss + q2_loss
#     457
# --> 458         critic_loss.backward()
#     459
#     460         self.critic_1_optimizer.step()
#
# ~/.local/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~/.local/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
agent = Agent(error_state.shape[0],chkpt_dir = "obstacle_model",device='cpu')
# Out:
# cpu

# %%
agent.load_models()
# Out:
# ..loading...
# ..loading...
# ..loading...
# ..loading...
# ..loading...
# ..loading...

# %%
k = abs(agent.actor.mu.weight[0].item())

# %%
# k final model :
k
# Out:
# 3.006781578063965

# %%
ki= abs(agent.actor.mu.weight[1].item())
#final model ki : 
ki
# Out:
# 1.22925865650177

# %%
kd = abs(agent.actor.mu.weight[2].item())
#final model kd : 
kd
# Out:
# 0.37681442499160767

# %%
agent.save_models()
# Out:
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...
# ...saving...

# %%
abs(agent.actor.mu.weight[1].item())
# Out:
# 1.22925865650177

# %%
#kd= 6.574056625366211
#num_steps = 0

# %%
for i in range(3000): 
    
    a = np.random.uniform(-30,30,4)
    
    b = np.random.uniform(0,90,2)
    
    spatial_state = State(a[0],a[1],np.radians(b[0]))
    
    target = State(a[2],a[3],np.radians(b[1]))
    
    controller = Controller(target,spatial_state)
    
    done = False 
    num_steps = 0
    
    while not done: 
        
        w = controller.iterate_with_gains(k,ki,kd)
        
        controller.make_action(w) 
        
        done = controller.isArrived() 
        
        #if done: 
            
            #print("episode ",i," success")
            
        num_steps +=1 
        
        if num_steps>=800: 
            
            done = True 
            
            print("Target not reached")
        
        controller.track_route() 
        
       # if(done): 
        
         #   a,b,c = controller.give_route()
         #   parkour = Parkour()
         #   parkour.drawPlot(a, b, c, targetX=target.x,targetY=target.y,targetT=target.theta, show=True)
